# %% [markdown]
# # 🎯 Complete Improved Multimodal Deepfake Detection - All Datasets
#
# ## 🆕 Key Improvements in This Notebook
#
# ### ✅ Addressed Issues:
# 1. **Class Balancing (Highest Priority)** - Multiple strategies implemented
# 2. **Focal Loss** - Addresses hard examples and class imbalance
# 3. **Class Weights** - Automatic computation for each dataset
# 4. **Threshold Tuning** - Optimized decision thresholds
# 5. **Comprehensive Results Analysis** - Detailed metrics and visualizations
#
# ### 📊 Datasets Used:
# 1. **Deepfake Image Detection Dataset** (Images)
# 2. **FaceForensics++** (Videos/Images)
# 3. **Celeb-DF V2** (Videos)
# 4. **FakeAVCeleb** (Audio-Visual)
# 5. **DFD** (Videos)
# 6. **DeepFake_Audio Dataset** (Audio)
#
# ### 🎓 Techniques Applied:
# - **Data Augmentation** for minority class
# - **Focal Loss** (γ=2, α=0.25)
# - **Class Weights** (sklearn.utils.class_weight)
# - **Threshold Optimization** (F1, Youden's J)
# - **SMOTE** for severe imbalance
# - **Stratified Sampling** throughout
# - **Early Fusion + Late Fusion** multimodal approaches

# %% [markdown]
# ## 📦 Installation & Setup

# %%
# Install required packages
# !pip install torch torchvision torchaudio
# !pip install opencv-python librosa soundfile
# !pip install scikit-learn imbalanced-learn
# !pip install matplotlib seaborn pandas numpy
# !pip install pillow tqdm facenet-pytorch
# !pip install timm efficientnet-pytorch
# Out:
# Requirement already satisfied: torch in c:\users\akshay-stu\miniconda3\envs\dl\lib\site-packages (2.9.1+cu128)
# Requirement already satisfied: torchvision in c:\users\akshay-stu\miniconda3\envs\dl\lib\site-packages (0.24.1+cu128)
# Requirement already satisfied: torchaudio in c:\users\akshay-stu\miniconda3\envs\dl\lib\site-packages (2.9.1+cu128)
# Requirement already satisfied: filelock in c:\users\akshay-stu\miniconda3\envs\dl\lib\site-packages (from torch) (3.19.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in c:\users\akshay-stu\miniconda3\envs\dl\lib\site-packages (from torch) (4.15.0)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\akshay-stu\miniconda3\envs\dl\lib\site-packages (from torch) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in c:\users\akshay-stu\miniconda3\envs\dl\lib\site-packages (from torch) (3.3)
# Requirement already satisfied: jinja2 in c:\users\akshay-stu\miniconda3\envs\dl\lib\site-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in c:\users\akshay-stu\miniconda3\envs\dl\lib\site-packages (from torch) (2025.9.0)
# Requirement already satisfied: numpy in c:\users\akshay-stu\miniconda3\envs\dl\lib\site-packages (from torchvision) (2.1.2)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in c:\users\akshay-stu\miniconda3\envs\dl\lib\site-packages (from torchvision) (11.3.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\akshay-stu\miniconda3\envs\dl\lib\site-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\akshay-stu\miniconda3\envs\dl\lib\site-packages (from jinja2->torch) (2.1.5)
# Requirement already satisfied: opencv-python in c:\users\akshay-stu\miniconda3\envs\dl\lib\site-packages (4.12.0.88)
# Requirement already satisfied: librosa in c:\users\akshay-stu\miniconda3\envs\dl\lib\site-packages (0.11.0)
# Requirement already satisfied: soundfile in c:\users\akshay-stu\miniconda3\envs\dl\lib\site-packages (0.13.1)
# Requirement already satisfied: numpy<2.3.0,>=2 in c:\users\akshay-stu\miniconda3\envs\dl\lib\site-packages (from opencv-python) (2.1.2)
# Requirement already satisfied: audioread>=2.1.9 in c:\users\akshay-stu\miniconda3\envs\dl\lib\site-packages (from librosa) (3.1.0)
# Requirement already satisfied: numba>=0.51.0 in c:\users\akshay-stu\miniconda3\envs\dl\lib\site-packages (from librosa) (0.62.1)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\akshay-stu\miniconda3\envs\dl\lib\site-packages (from librosa) (1.15.3)
# Requirement already satisfied: scikit-learn>=1.1.0 in c:\users\akshay-stu\miniconda3\envs\dl\lib\site-packages (from librosa) (1.7.2)
# Requirement already satisfied: joblib>=1.0 in c:\users\akshay-stu\miniconda3\envs\dl\lib\site-packages (from librosa) (1.5.2)
# Requirement already satisfied: decorator>=4.3.0 in c:\users\akshay-stu\miniconda3\envs\dl\lib\site-packages (from librosa) (5.2.1)
# Requirement already satisfied: pooch>=1.1 in c:\users\akshay-stu\miniconda3\envs\dl\lib\site-packages (from librosa) (1.8.2)
# Requirement already satisfied: soxr>=0.3.2 in c:\users\akshay-stu\miniconda3\envs\dl\lib\site-packages (from librosa) (1.0.0)
# Requirement already satisfied: typing_extensions>=4.1.1 in c:\users\akshay-stu\miniconda3\envs\dl\lib\site-packages (from librosa) (4.15.0)
# Requirement already satisfied: lazy_loader>=0.1 in c:\users\akshay-stu\miniconda3\envs\dl\lib\site-packages (from librosa) (0.4)
# Requirement already satisfied: msgpack>=1.0 in c:\users\akshay-stu\miniconda3\envs\dl\lib\site-packages (from librosa) (1.1.2)
# Requirement already satisfied: cffi>=1.0 in c:\users\akshay-stu\miniconda3\envs\dl\lib\site-packages (from soundfile) (2.0.0)
# Requirement already satisfied: pycparser in c:\users\akshay-stu\miniconda3\envs\dl\lib\site-packages (from cffi>=1.0->soundfile) (2.23)
# Requirement already satisfied: packaging in c:\users\akshay-stu\miniconda3\envs\dl\lib\site-packages (from lazy_loader>=0.1->librosa) (25.0)
# Requirement already satisfied: llvmlite<0.46,>=0.45.0dev0 in c:\users\akshay-stu\miniconda3\envs\dl\lib\site-packages (from numba>=0.51.0->librosa) (0.45.1)
# Requirement already satisfied: platformdirs>=2.5.0 in c:\users\akshay-stu\miniconda3\envs\dl\lib\site-packages (from pooch>=1.1->librosa) (4.5.0)
# Requirement already satisfied: requests>=2.19.0 in c:\users\akshay-stu\miniconda3\envs\dl\lib\site-packages (from pooch>=1.1->librosa) (2.32.5)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\akshay-stu\miniconda3\envs\dl\lib\site-packages (from requests>=2.19.0->pooch>=1.1->librosa) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\akshay-stu\miniconda3\envs\dl\lib\site-packages (from requests>=2.19.0->pooch>=1.1->librosa) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\akshay-stu\miniconda3\envs\dl\lib\site-packages (from requests>=2.19.0->pooch>=1.1->librosa) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\akshay-stu\miniconda3\envs\dl\lib\site-packages (from requests>=2.19.0->pooch>=1.1->librosa) (2025.11.12)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\akshay-stu\miniconda3\envs\dl\lib\site-packages (from scikit-learn>=1.1.0->librosa) (3.6.0)
# Requirement already satisfied: scikit-learn in c:\users\akshay-stu\miniconda3\envs\dl\lib\site-packages (1.7.2)
# Requirement already satisfied: imbalanced-learn in c:\users\akshay-stu\miniconda3\envs\dl\lib\site-packages (0.14.0)
# Requirement already satisfied: numpy>=1.22.0 in c:\users\akshay-stu\miniconda3\envs\dl\lib\site-packages (from scikit-learn) (2.1.2)
# Requirement already satisfied: scipy>=1.8.0 in c:\users\akshay-stu\miniconda3\envs\dl\lib\site-packages (from scikit-learn) (1.15.3)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\akshay-stu\miniconda3\envs\dl\lib\site-packages (from scikit-learn) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\akshay-stu\miniconda3\envs\dl\lib\site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: matplotlib in c:\users\akshay-stu\miniconda3\envs\dl\lib\site-packages (3.10.7)
# Requirement already satisfied: seaborn in c:\users\akshay-stu\miniconda3\envs\dl\lib\site-packages (0.13.2)
# Requirement already satisfied: pandas in c:\users\akshay-stu\miniconda3\envs\dl\lib\site-packages (2.3.3)
# Requirement already satisfied: numpy in c:\users\akshay-stu\miniconda3\envs\dl\lib\site-packages (2.1.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\akshay-stu\miniconda3\envs\dl\lib\site-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\akshay-stu\miniconda3\envs\dl\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\akshay-stu\miniconda3\envs\dl\lib\site-packages (from matplotlib) (4.61.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\akshay-stu\miniconda3\envs\dl\lib\site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\akshay-stu\miniconda3\envs\dl\lib\site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\akshay-stu\miniconda3\envs\dl\lib\site-packages (from matplotlib) (11.3.0)
# Requirement already satisfied: pyparsing>=3 in c:\users\akshay-stu\miniconda3\envs\dl\lib\site-packages (from matplotlib) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\akshay-stu\miniconda3\envs\dl\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\akshay-stu\miniconda3\envs\dl\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\akshay-stu\miniconda3\envs\dl\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\akshay-stu\miniconda3\envs\dl\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Requirement already satisfied: pillow in c:\users\akshay-stu\miniconda3\envs\dl\lib\site-packages (11.3.0)
# Requirement already satisfied: tqdm in c:\users\akshay-stu\miniconda3\envs\dl\lib\site-packages (4.67.1)
# Collecting facenet-pytorch
#   Downloading facenet_pytorch-2.6.0-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: colorama in c:\users\akshay-stu\miniconda3\envs\dl\lib\site-packages (from tqdm) (0.4.6)
# Collecting numpy<2.0.0,>=1.24.0 (from facenet-pytorch)
#   Downloading numpy-1.26.4-cp310-cp310-win_amd64.whl.metadata (61 kB)
# Collecting pillow
#   Downloading pillow-10.2.0-cp310-cp310-win_amd64.whl.metadata (9.9 kB)
# Requirement already satisfied: requests<3.0.0,>=2.0.0 in c:\users\akshay-stu\miniconda3\envs\dl\lib\site-packages (from facenet-pytorch) (2.32.5)
# Collecting torch<2.3.0,>=2.2.0 (from facenet-pytorch)
#   Downloading torch-2.2.2-cp310-cp310-win_amd64.whl.metadata (26 kB)
# Collecting torchvision<0.18.0,>=0.17.0 (from facenet-pytorch)
#   Downloading torchvision-0.17.2-cp310-cp310-win_amd64.whl.metadata (6.6 kB)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\akshay-stu\miniconda3\envs\dl\lib\site-packages (from requests<3.0.0,>=2.0.0->facenet-pytorch) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\akshay-stu\miniconda3\envs\dl\lib\site-packages (from requests<3.0.0,>=2.0.0->facenet-pytorch) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\akshay-stu\miniconda3\envs\dl\lib\site-packages (from requests<3.0.0,>=2.0.0->facenet-pytorch) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\akshay-stu\miniconda3\envs\dl\lib\site-packages (from requests<3.0.0,>=2.0.0->facenet-pytorch) (2025.11.12)
# Requirement already satisfied: filelock in c:\users\akshay-stu\miniconda3\envs\dl\lib\site-packages (from torch<2.3.0,>=2.2.0->facenet-pytorch) (3.19.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in c:\users\akshay-stu\miniconda3\envs\dl\lib\site-packages (from torch<2.3.0,>=2.2.0->facenet-pytorch) (4.15.0)
# Requirement already satisfied: sympy in c:\users\akshay-stu\miniconda3\envs\dl\lib\site-packages (from torch<2.3.0,>=2.2.0->facenet-pytorch) (1.14.0)
# Requirement already satisfied: networkx in c:\users\akshay-stu\miniconda3\envs\dl\lib\site-packages (from torch<2.3.0,>=2.2.0->facenet-pytorch) (3.3)
# Requirement already satisfied: jinja2 in c:\users\akshay-stu\miniconda3\envs\dl\lib\site-packages (from torch<2.3.0,>=2.2.0->facenet-pytorch) (3.1.6)
# Requirement already satisfied: fsspec in c:\users\akshay-stu\miniconda3\envs\dl\lib\site-packages (from torch<2.3.0,>=2.2.0->facenet-pytorch) (2025.9.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\akshay-stu\miniconda3\envs\dl\lib\site-packages (from jinja2->torch<2.3.0,>=2.2.0->facenet-pytorch) (2.1.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\akshay-stu\miniconda3\envs\dl\lib\site-packages (from sympy->torch<2.3.0,>=2.2.0->facenet-pytorch) (1.3.0)
# Downloading facenet_pytorch-2.6.0-py3-none-any.whl (1.9 MB)
#    ---------------------------------------- 0.0/1.9 MB ? eta -:--:--
#    ---------------------------------------- 1.9/1.9 MB 20.8 MB/s  0:00:00
# Downloading pillow-10.2.0-cp310-cp310-win_amd64.whl (2.6 MB)
#    ---------------------------------------- 0.0/2.6 MB ? eta -:--:--
#    ---------------------------------------- 2.6/2.6 MB 29.9 MB/s  0:00:00
# Downloading numpy-1.26.4-cp310-cp310-win_amd64.whl (15.8 MB)
#    ---------------------------------------- 0.0/15.8 MB ? eta -:--:--
#    -------------------------------- ------- 12.8/15.8 MB 57.7 MB/s eta 0:00:01
#    ---------------------------------------- 15.8/15.8 MB 47.4 MB/s  0:00:00
# Downloading torch-2.2.2-cp310-cp310-win_amd64.whl (198.6 MB)
#    ---------------------------------------- 0.0/198.6 MB ? eta -:--:--
#    - -------------------------------------- 8.1/198.6 MB 42.1 MB/s eta 0:00:05
#    --- ------------------------------------ 17.8/198.6 MB 41.6 MB/s eta 0:00:05
#    ----- ---------------------------------- 27.5/198.6 MB 42.5 MB/s eta 0:00:05
#    ------- -------------------------------- 36.7/198.6 MB 44.0 MB/s eta 0:00:04
#    ------- -------------------------------- 36.7/198.6 MB 44.0 MB/s eta 0:00:04
#    ------- -------------------------------- 36.7/198.6 MB 44.0 MB/s eta 0:00:04
#    ------- -------------------------------- 36.7/198.6 MB 44.0 MB/s eta 0:00:04
#    ------- -------------------------------- 36.7/198.6 MB 44.0 MB/s eta 0:00:04
#    ------- -------------------------------- 36.7/198.6 MB 44.0 MB/s eta 0:00:04
#    ------- -------------------------------- 36.7/198.6 MB 44.0 MB/s eta 0:00:04
#    -------- ------------------------------- 44.3/198.6 MB 18.8 MB/s eta 0:00:09
#    ----------- ---------------------------- 56.1/198.6 MB 21.8 MB/s eta 0:00:07
#    ------------- -------------------------- 67.9/198.6 MB 24.3 MB/s eta 0:00:06
#    -------------- ------------------------- 73.1/198.6 MB 24.3 MB/s eta 0:00:06
#    ---------------- ----------------------- 82.1/198.6 MB 25.4 MB/s eta 0:00:05
#    ----------------- ---------------------- 89.1/198.6 MB 25.9 MB/s eta 0:00:05
#    ------------------- -------------------- 95.9/198.6 MB 26.3 MB/s eta 0:00:04
#    -------------------- ------------------ 104.1/198.6 MB 26.9 MB/s eta 0:00:04
#    --------------------- ----------------- 108.0/198.6 MB 27.4 MB/s eta 0:00:04
#    --------------------- ----------------- 108.0/198.6 MB 27.4 MB/s eta 0:00:04
#    --------------------- ----------------- 108.0/198.6 MB 27.4 MB/s eta 0:00:04
#    --------------------- ----------------- 110.4/198.6 MB 23.3 MB/s eta 0:00:04
#    ----------------------- --------------- 118.2/198.6 MB 23.9 MB/s eta 0:00:04
#    ------------------------ -------------- 124.0/198.6 MB 24.1 MB/s eta 0:00:04
#    ------------------------- ------------- 127.7/198.6 MB 23.7 MB/s eta 0:00:03
#    -------------------------- ------------ 135.0/198.6 MB 24.1 MB/s eta 0:00:03
#    ---------------------------- ---------- 143.4/198.6 MB 24.6 MB/s eta 0:00:03
#    ----------------------------- --------- 151.8/198.6 MB 25.1 MB/s eta 0:00:02
#    ------------------------------- ------- 160.2/198.6 MB 25.6 MB/s eta 0:00:02
#    --------------------------------- ----- 168.6/198.6 MB 26.1 MB/s eta 0:00:02
#    ---------------------------------- ---- 174.9/198.6 MB 26.2 MB/s eta 0:00:01
#    ----------------------------------- --- 182.2/198.6 MB 26.4 MB/s eta 0:00:01
#    ------------------------------------- - 190.1/198.6 MB 26.8 MB/s eta 0:00:01
#    --------------------------------------  195.8/198.6 MB 26.8 MB/s eta 0:00:01
#    --------------------------------------  198.4/198.6 MB 26.7 MB/s eta 0:00:01
#    --------------------------------------  198.4/198.6 MB 26.7 MB/s eta 0:00:01
#    ---------------------------------------- 198.6/198.6 MB 25.4 MB/s  0:00:07
# Downloading torchvision-0.17.2-cp310-cp310-win_amd64.whl (1.2 MB)
#    ---------------------------------------- 0.0/1.2 MB ? eta -:--:--
#    ---------------------------------------- 1.2/1.2 MB 14.6 MB/s  0:00:00
# Installing collected packages: pillow, numpy, torch, torchvision, facenet-pytorch
#
#   Attempting uninstall: pillow
#
#     Found existing installation: pillow 11.3.0
#
#     Uninstalling pillow-11.3.0:
#
#       Successfully uninstalled pillow-11.3.0
#
#    ---------------------------------------- 0/5 [pillow]
#    ---------------------------------------- 0/5 [pillow]
#    ---------------------------------------- 0/5 [pillow]
#    ---------------------------------------- 0/5 [pillow]
#    ---------------------------------------- 0/5 [pillow]
#    ---------------------------------------- 0/5 [pillow]
#    ---------------------------------------- 0/5 [pillow]
#    ---------------------------------------- 0/5 [pillow]
#    ---------------------------------------- 0/5 [pillow]
#    ---------------------------------------- 0/5 [pillow]
#    ---------------------------------------- 0/5 [pillow]
#    ---------------------------------------- 0/5 [pillow]
#    ---------------------------------------- 0/5 [pillow]
#    ---------------------------------------- 0/5 [pillow]
#    ---------------------------------------- 0/5 [pillow]
#    ---------------------------------------- 0/5 [pillow]
#    ---------------------------------------- 0/5 [pillow]
#    ---------------------------------------- 0/5 [pillow]
#    ---------------------------------------- 0/5 [pillow]
#    ---------------------------------------- 0/5 [pillow]
#    ---------------------------------------- 0/5 [pillow]
#    ---------------------------------------- 0/5 [pillow]
#    ---------------------------------------- 0/5 [pillow]
#    ---------------------------------------- 0/5 [pillow]
#   Attempting uninstall: numpy
#    ---------------------------------------- 0/5 [pillow]
#     Found existing installation: numpy 2.1.2
#    ---------------------------------------- 0/5 [pillow]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#     Uninstalling numpy-2.1.2:
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#       Successfully uninstalled numpy-2.1.2
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#   Attempting uninstall: torch
#    -------- ------------------------------- 1/5 [numpy]
#     Found existing installation: torch 2.9.1+cu128
#    -------- ------------------------------- 1/5 [numpy]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#     Uninstalling torch-2.9.1+cu128:
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#       Successfully uninstalled torch-2.9.1+cu128
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#   Attempting uninstall: torchvision
#    ---------------- ----------------------- 2/5 [torch]
#     Found existing installation: torchvision 0.24.1+cu128
#    ---------------- ----------------------- 2/5 [torch]
#    ------------------------ --------------- 3/5 [torchvision]
#     Uninstalling torchvision-0.24.1+cu128:
#    ------------------------ --------------- 3/5 [torchvision]
#       Successfully uninstalled torchvision-0.24.1+cu128
#    ------------------------ --------------- 3/5 [torchvision]
#    ------------------------ --------------- 3/5 [torchvision]
#    ------------------------ --------------- 3/5 [torchvision]
#    ------------------------ --------------- 3/5 [torchvision]
#    ------------------------ --------------- 3/5 [torchvision]
#    ------------------------ --------------- 3/5 [torchvision]
#    ------------------------ --------------- 3/5 [torchvision]
#    ------------------------ --------------- 3/5 [torchvision]
#    ------------------------ --------------- 3/5 [torchvision]
#    ------------------------ --------------- 3/5 [torchvision]
#    ------------------------ --------------- 3/5 [torchvision]
#    ------------------------ --------------- 3/5 [torchvision]
#    ------------------------ --------------- 3/5 [torchvision]
#    ------------------------ --------------- 3/5 [torchvision]
#    ------------------------ --------------- 3/5 [torchvision]
#    ------------------------ --------------- 3/5 [torchvision]
#    ------------------------ --------------- 3/5 [torchvision]
#    ------------------------ --------------- 3/5 [torchvision]
#    ------------------------ --------------- 3/5 [torchvision]
#    ------------------------ --------------- 3/5 [torchvision]
#    ------------------------ --------------- 3/5 [torchvision]
#    ------------------------ --------------- 3/5 [torchvision]
#    ------------------------ --------------- 3/5 [torchvision]
#    ------------------------ --------------- 3/5 [torchvision]
#    ------------------------ --------------- 3/5 [torchvision]
#    ------------------------ --------------- 3/5 [torchvision]
#    ------------------------ --------------- 3/5 [torchvision]
#    ------------------------ --------------- 3/5 [torchvision]
#    ------------------------ --------------- 3/5 [torchvision]
#    ------------------------ --------------- 3/5 [torchvision]
#    -------------------------------- ------- 4/5 [facenet-pytorch]
#    ---------------------------------------- 5/5 [facenet-pytorch]
#
# Successfully installed facenet-pytorch-2.6.0 numpy-1.26.4 pillow-10.2.0 torch-2.2.2 torchvision-0.17.2
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\akshay-stu\miniconda3\envs\dl\Lib\site-packages\~il'.
#   You can safely remove it manually.
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\akshay-stu\miniconda3\envs\dl\Lib\site-packages\~umpy.libs'.
#   You can safely remove it manually.
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\akshay-stu\miniconda3\envs\dl\Lib\site-packages\~umpy'.
#   You can safely remove it manually.
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\akshay-stu\miniconda3\envs\dl\Lib\site-packages\~orch'.
#   You can safely remove it manually.
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\akshay-stu\miniconda3\envs\dl\Lib\site-packages\~orchvision'.
#   You can safely remove it manually.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# opencv-python 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# torchaudio 2.9.1+cu128 requires torch==2.9.1, but you have torch 2.2.2 which is incompatible.
# Requirement already satisfied: timm in c:\users\akshay-stu\miniconda3\envs\dl\lib\site-packages (1.0.22)
# Collecting efficientnet-pytorch
#   Downloading efficientnet_pytorch-0.7.1.tar.gz (21 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: torch in c:\users\akshay-stu\miniconda3\envs\dl\lib\site-packages (from timm) (2.2.2)
# Requirement already satisfied: torchvision in c:\users\akshay-stu\miniconda3\envs\dl\lib\site-packages (from timm) (0.17.2)
# Requirement already satisfied: pyyaml in c:\users\akshay-stu\miniconda3\envs\dl\lib\site-packages (from timm) (6.0.3)
# Requirement already satisfied: huggingface_hub in c:\users\akshay-stu\miniconda3\envs\dl\lib\site-packages (from timm) (0.36.0)
# Requirement already satisfied: safetensors in c:\users\akshay-stu\miniconda3\envs\dl\lib\site-packages (from timm) (0.7.0)
# Requirement already satisfied: filelock in c:\users\akshay-stu\miniconda3\envs\dl\lib\site-packages (from huggingface_hub->timm) (3.19.1)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\akshay-stu\miniconda3\envs\dl\lib\site-packages (from huggingface_hub->timm) (2025.9.0)
# Requirement already satisfied: packaging>=20.9 in c:\users\akshay-stu\miniconda3\envs\dl\lib\site-packages (from huggingface_hub->timm) (25.0)
# Requirement already satisfied: requests in c:\users\akshay-stu\miniconda3\envs\dl\lib\site-packages (from huggingface_hub->timm) (2.32.5)
# Requirement already satisfied: tqdm>=4.42.1 in c:\users\akshay-stu\miniconda3\envs\dl\lib\site-packages (from huggingface_hub->timm) (4.67.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\akshay-stu\miniconda3\envs\dl\lib\site-packages (from huggingface_hub->timm) (4.15.0)
# Requirement already satisfied: colorama in c:\users\akshay-stu\miniconda3\envs\dl\lib\site-packages (from tqdm>=4.42.1->huggingface_hub->timm) (0.4.6)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\akshay-stu\miniconda3\envs\dl\lib\site-packages (from requests->huggingface_hub->timm) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\akshay-stu\miniconda3\envs\dl\lib\site-packages (from requests->huggingface_hub->timm) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\akshay-stu\miniconda3\envs\dl\lib\site-packages (from requests->huggingface_hub->timm) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\akshay-stu\miniconda3\envs\dl\lib\site-packages (from requests->huggingface_hub->timm) (2025.11.12)
# Requirement already satisfied: sympy in c:\users\akshay-stu\miniconda3\envs\dl\lib\site-packages (from torch->timm) (1.14.0)
# Requirement already satisfied: networkx in c:\users\akshay-stu\miniconda3\envs\dl\lib\site-packages (from torch->timm) (3.3)
# Requirement already satisfied: jinja2 in c:\users\akshay-stu\miniconda3\envs\dl\lib\site-packages (from torch->timm) (3.1.6)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\akshay-stu\miniconda3\envs\dl\lib\site-packages (from jinja2->torch->timm) (2.1.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\akshay-stu\miniconda3\envs\dl\lib\site-packages (from sympy->torch->timm) (1.3.0)
# Requirement already satisfied: numpy in c:\users\akshay-stu\miniconda3\envs\dl\lib\site-packages (from torchvision->timm) (1.26.4)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in c:\users\akshay-stu\miniconda3\envs\dl\lib\site-packages (from torchvision->timm) (10.2.0)
# Building wheels for collected packages: efficientnet-pytorch
#   Building wheel for efficientnet-pytorch (pyproject.toml): started
#   Building wheel for efficientnet-pytorch (pyproject.toml): finished with status 'done'
#   Created wheel for efficientnet-pytorch: filename=efficientnet_pytorch-0.7.1-py3-none-any.whl size=16519 sha256=8d5525e96904f454c325c9d21f5fcaafd7987db04309a25e996b9ef03641060d
#   Stored in directory: c:\users\akshay-stu\appdata\local\pip\cache\wheels\03\3f\e9\911b1bc46869644912bda90a56bcf7b960f20b5187feea3baf
# Successfully built efficientnet-pytorch
# Installing collected packages: efficientnet-pytorch
# Successfully installed efficientnet-pytorch-0.7.1

# %%
import torch
print(f"PyTorch version: {torch.__version__}")
print(f"CUDA available: {torch.cuda.is_available()}")
if torch.cuda.is_available():
    print(f"CUDA version: {torch.version.cuda}")
    print(f"GPU: {torch.cuda.get_device_name(0)}")
    print(f"GPU Memory: {torch.cuda.get_device_properties(0).total_memory / 1e9:.2f} GB")
else:
    print("⚠️ WARNING: CUDA not available - using CPU")
# Out:
# PyTorch version: 2.2.2+cpu
# CUDA available: False
# ⚠️ WARNING: CUDA not available - using CPU

# %% [markdown]
# ## 📚 Import Libraries

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from tqdm import tqdm
import warnings
warnings.filterwarnings('ignore')

# PyTorch
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader, WeightedRandomSampler
import torchvision.transforms as transforms
from torchvision import models

# Image/Video/Audio processing
import cv2
from PIL import Image
import librosa
import soundfile as sf

# Sklearn
from sklearn.model_selection import train_test_split, StratifiedKFold
from sklearn.metrics import (
    accuracy_score, precision_score, recall_score, f1_score,
    confusion_matrix, classification_report, roc_curve, auc,
    precision_recall_curve, average_precision_score
)
from sklearn.utils.class_weight import compute_class_weight
from imblearn.over_sampling import SMOTE, RandomOverSampler
from imblearn.under_sampling import RandomUnderSampler

# Set random seeds for reproducibility
torch.manual_seed(42)
np.random.seed(42)

# Device configuration
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"Using device: {device}")
if torch.cuda.is_available():
    print(f"GPU: {torch.cuda.get_device_name(0)}")
    print(f"Memory: {torch.cuda.get_device_properties(0).total_memory / 1e9:.2f} GB")
# Out:
# Using device: cpu

# %% [markdown]
# ## 📊 Dataset Statistics & Paths
#
# ### Current Dataset Distribution:
#
# **Note:** These numbers will be verified and displayed in the data loading cells below.

# %%
# Dataset paths configuration
DATASET_PATHS = {
    'deepfake_images': {
        'train_real': '../Deepfake image detection dataset/train-20250112T065955Z-001/train/real',
        'train_fake': '../Deepfake image detection dataset/train-20250112T065955Z-001/train/fake',
        'test_real': '../Deepfake image detection dataset/test-20250112T065939Z-001/test/real',
        'test_fake': '../Deepfake image detection dataset/test-20250112T065939Z-001/test/fake'
    },
    'faceforensics': {
        'original': '../FaceForensics++/FaceForensics++_C23/original',
        'deepfakes': '../FaceForensics++/FaceForensics++_C23/Deepfakes',
        'face2face': '../FaceForensics++/FaceForensics++_C23/Face2Face',
        'faceswap': '../FaceForensics++/FaceForensics++_C23/FaceSwap',
        'neuraltextures': '../FaceForensics++/FaceForensics++_C23/NeuralTextures'
    },
    'celebdf': {
        'celeb_real': '../Celeb V2/Celeb-real',
        'youtube_real': '../Celeb V2/YouTube-real',
        'celeb_synthesis': '../Celeb V2/Celeb-synthesis'
    },
    'dfd': {
        'original': '../DFD/DFD_original sequences',
        'manipulated': '../DFD/DFD_manipulated_sequences/DFD_manipulated_sequences'
    },
    'audio': {
        'real': '../DeepFake_AudioDataset/KAGGLE/AUDIO/REAL',
        'fake': '../DeepFake_AudioDataset/KAGGLE/AUDIO/FAKE'
    },
    'fakeavceleb': {
        'real_av': '../FakeAVCeleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/RealVideo-RealAudio',
        'fake_vv_aa': '../FakeAVCeleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio',
        'fake_v_ra': '../FakeAVCeleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-RealAudio',
        'fake_rv_a': '../FakeAVCeleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/RealVideo-FakeAudio'
    }
}

print("✅ Dataset paths configured successfully!")

# %% [markdown]
# ## 🔧 Utility Functions

# %%
def count_files_in_directory(directory, extensions=None):
    """Count files in a directory with optional extension filter."""
    if not os.path.exists(directory):
        return 0
    
    if extensions is None:
        extensions = ['.jpg', '.jpeg', '.png', '.mp4', '.avi', '.mov', '.wav', '.mp3', '.flac']
    
    count = 0
    for root, dirs, files in os.walk(directory):
        for file in files:
            if any(file.lower().endswith(ext) for ext in extensions):
                count += 1
    return count

def get_dataset_statistics():
    """Get comprehensive statistics for all datasets."""
    stats = {}
    
    # Deepfake Images
    print("📊 Counting Deepfake Image Detection Dataset...")
    stats['deepfake_images'] = {
        'train_real': count_files_in_directory(DATASET_PATHS['deepfake_images']['train_real'], ['.jpg', '.jpeg', '.png']),
        'train_fake': count_files_in_directory(DATASET_PATHS['deepfake_images']['train_fake'], ['.jpg', '.jpeg', '.png']),
        'test_real': count_files_in_directory(DATASET_PATHS['deepfake_images']['test_real'], ['.jpg', '.jpeg', '.png']),
        'test_fake': count_files_in_directory(DATASET_PATHS['deepfake_images']['test_fake'], ['.jpg', '.jpeg', '.png'])
    }
    
    # FaceForensics++
    print("📊 Counting FaceForensics++...")
    stats['faceforensics'] = {
        'original': count_files_in_directory(DATASET_PATHS['faceforensics']['original']),
        'deepfakes': count_files_in_directory(DATASET_PATHS['faceforensics']['deepfakes']),
        'face2face': count_files_in_directory(DATASET_PATHS['faceforensics']['face2face']),
        'faceswap': count_files_in_directory(DATASET_PATHS['faceforensics']['faceswap']),
        'neuraltextures': count_files_in_directory(DATASET_PATHS['faceforensics']['neuraltextures'])
    }
    
    # Celeb-DF V2
    print("📊 Counting Celeb-DF V2...")
    stats['celebdf'] = {
        'celeb_real': count_files_in_directory(DATASET_PATHS['celebdf']['celeb_real']),
        'youtube_real': count_files_in_directory(DATASET_PATHS['celebdf']['youtube_real']),
        'celeb_synthesis': count_files_in_directory(DATASET_PATHS['celebdf']['celeb_synthesis'])
    }
    
    # DFD
    print("📊 Counting DFD...")
    stats['dfd'] = {
        'original': count_files_in_directory(DATASET_PATHS['dfd']['original']),
        'manipulated': count_files_in_directory(DATASET_PATHS['dfd']['manipulated'])
    }
    
    # Audio
    print("📊 Counting DeepFake Audio Dataset...")
    stats['audio'] = {
        'real': count_files_in_directory(DATASET_PATHS['audio']['real'], ['.wav', '.mp3', '.flac']),
        'fake': count_files_in_directory(DATASET_PATHS['audio']['fake'], ['.wav', '.mp3', '.flac'])
    }
    
    # FakeAVCeleb
    print("📊 Counting FakeAVCeleb...")
    stats['fakeavceleb'] = {
        'real_av': count_files_in_directory(DATASET_PATHS['fakeavceleb']['real_av']),
        'fake_vv_aa': count_files_in_directory(DATASET_PATHS['fakeavceleb']['fake_vv_aa']),
        'fake_v_ra': count_files_in_directory(DATASET_PATHS['fakeavceleb']['fake_v_ra']),
        'fake_rv_a': count_files_in_directory(DATASET_PATHS['fakeavceleb']['fake_rv_a'])
    }
    
    return stats

def print_dataset_statistics(stats):
    """Print formatted dataset statistics with class imbalance ratio."""
    print("\n" + "="*80)
    print("📊 COMPREHENSIVE DATASET STATISTICS")
    print("="*80)
    
    # Deepfake Images
    print("\n1️⃣  DEEPFAKE IMAGE DETECTION DATASET")
    train_real = stats['deepfake_images']['train_real']
    train_fake = stats['deepfake_images']['train_fake']
    test_real = stats['deepfake_images']['test_real']
    test_fake = stats['deepfake_images']['test_fake']
    print(f"   Train Real: {train_real:,}")
    print(f"   Train Fake: {train_fake:,}")
    print(f"   Test Real:  {test_real:,}")
    print(f"   Test Fake:  {test_fake:,}")
    print(f"   Total:      {train_real + train_fake + test_real + test_fake:,}")
    if train_fake > 0:
        print(f"   ⚠️  Train Imbalance Ratio (Real:Fake): {train_real/train_fake:.2f}:1")
    
    # FaceForensics++
    print("\n2️⃣  FACEFORENSICS++")
    ff_original = stats['faceforensics']['original']
    ff_deepfakes = stats['faceforensics']['deepfakes']
    ff_face2face = stats['faceforensics']['face2face']
    ff_faceswap = stats['faceforensics']['faceswap']
    ff_neural = stats['faceforensics']['neuraltextures']
    ff_total_fake = ff_deepfakes + ff_face2face + ff_faceswap + ff_neural
    print(f"   Original (Real):      {ff_original:,}")
    print(f"   Deepfakes (Fake):     {ff_deepfakes:,}")
    print(f"   Face2Face (Fake):     {ff_face2face:,}")
    print(f"   FaceSwap (Fake):      {ff_faceswap:,}")
    print(f"   NeuralTextures (Fake): {ff_neural:,}")
    print(f"   Total Fake:           {ff_total_fake:,}")
    print(f"   Total:                {ff_original + ff_total_fake:,}")
    if ff_total_fake > 0:
        print(f"   ⚠️  Imbalance Ratio (Real:Fake): {ff_original/ff_total_fake:.2f}:1")
    
    # Celeb-DF V2
    print("\n3️⃣  CELEB-DF V2")
    celeb_real = stats['celebdf']['celeb_real']
    youtube_real = stats['celebdf']['youtube_real']
    celeb_fake = stats['celebdf']['celeb_synthesis']
    total_real = celeb_real + youtube_real
    print(f"   Celeb-real:           {celeb_real:,}")
    print(f"   YouTube-real:         {youtube_real:,}")
    print(f"   Total Real:           {total_real:,}")
    print(f"   Celeb-synthesis (Fake): {celeb_fake:,}")
    print(f"   Total:                {total_real + celeb_fake:,}")
    if celeb_fake > 0:
        print(f"   ⚠️  Imbalance Ratio (Real:Fake): {total_real/celeb_fake:.2f}:1")
    
    # DFD
    print("\n4️⃣  DFD (DEEPFAKE DETECTION)")
    dfd_real = stats['dfd']['original']
    dfd_fake = stats['dfd']['manipulated']
    print(f"   Original (Real):      {dfd_real:,}")
    print(f"   Manipulated (Fake):   {dfd_fake:,}")
    print(f"   Total:                {dfd_real + dfd_fake:,}")
    if dfd_fake > 0:
        print(f"   ⚠️  Imbalance Ratio (Real:Fake): {dfd_real/dfd_fake:.2f}:1")
    
    # Audio
    print("\n5️⃣  DEEPFAKE AUDIO DATASET")
    audio_real = stats['audio']['real']
    audio_fake = stats['audio']['fake']
    print(f"   Real Audio:           {audio_real:,}")
    print(f"   Fake Audio:           {audio_fake:,}")
    print(f"   Total:                {audio_real + audio_fake:,}")
    if audio_fake > 0:
        print(f"   ⚠️  Imbalance Ratio (Real:Fake): {audio_real/audio_fake:.2f}:1")
    
    # FakeAVCeleb
    print("\n6️⃣  FAKEAVCELEB (AUDIO-VISUAL)")
    fav_real = stats['fakeavceleb']['real_av']
    fav_fake1 = stats['fakeavceleb']['fake_vv_aa']
    fav_fake2 = stats['fakeavceleb']['fake_v_ra']
    fav_fake3 = stats['fakeavceleb']['fake_rv_a']
    fav_total_fake = fav_fake1 + fav_fake2 + fav_fake3
    print(f"   RealVideo-RealAudio (Real):  {fav_real:,}")
    print(f"   FakeVideo-FakeAudio (Fake):  {fav_fake1:,}")
    print(f"   FakeVideo-RealAudio (Fake):  {fav_fake2:,}")
    print(f"   RealVideo-FakeAudio (Fake):  {fav_fake3:,}")
    print(f"   Total Fake:                  {fav_total_fake:,}")
    print(f"   Total:                       {fav_real + fav_total_fake:,}")
    if fav_total_fake > 0:
        print(f"   ⚠️  Imbalance Ratio (Real:Fake): {fav_real/fav_total_fake:.2f}:1")
    
    print("\n" + "="*80)

# Get and display statistics
print("🔍 Analyzing datasets... This may take a few minutes...")
dataset_stats = get_dataset_statistics()
print_dataset_statistics(dataset_stats)

# %% [markdown]
# ## 🎯 Focal Loss Implementation
#
# Focal Loss addresses class imbalance by down-weighting easy examples and focusing on hard examples.
#
# **Formula:** `FL(p_t) = -α_t * (1 - p_t)^γ * log(p_t)`
#
# Where:
# - `α`: Balancing factor for class imbalance (default: 0.25)
# - `γ`: Focusing parameter (default: 2.0)
# - `p_t`: Model's estimated probability for the true class

# %%
class FocalLoss(nn.Module):
    """Focal Loss for addressing class imbalance.
    
    Reference: Lin et al. "Focal Loss for Dense Object Detection" (2017)
    """
    def __init__(self, alpha=0.25, gamma=2.0, reduction='mean'):
        super(FocalLoss, self).__init__()
        self.alpha = alpha
        self.gamma = gamma
        self.reduction = reduction
    
    def forward(self, inputs, targets):
        BCE_loss = F.binary_cross_entropy_with_logits(inputs, targets, reduction='none')
        pt = torch.exp(-BCE_loss)  # Probability of correct class
        F_loss = self.alpha * (1 - pt) ** self.gamma * BCE_loss
        
        if self.reduction == 'mean':
            return F_loss.mean()
        elif self.reduction == 'sum':
            return F_loss.sum()
        else:
            return F_loss

class WeightedFocalLoss(nn.Module):
    """Focal Loss with class weights for severe imbalance."""
    def __init__(self, alpha=0.25, gamma=2.0, weight=None, reduction='mean'):
        super(WeightedFocalLoss, self).__init__()
        self.alpha = alpha
        self.gamma = gamma
        self.weight = weight
        self.reduction = reduction
    
    def forward(self, inputs, targets):
        BCE_loss = F.binary_cross_entropy_with_logits(inputs, targets, reduction='none')
        pt = torch.exp(-BCE_loss)
        F_loss = self.alpha * (1 - pt) ** self.gamma * BCE_loss
        
        if self.weight is not None:
            # Apply class weights
            weights = self.weight[targets.long()]
            F_loss = F_loss * weights
        
        if self.reduction == 'mean':
            return F_loss.mean()
        elif self.reduction == 'sum':
            return F_loss.sum()
        else:
            return F_loss

print("✅ Focal Loss implemented successfully!")
